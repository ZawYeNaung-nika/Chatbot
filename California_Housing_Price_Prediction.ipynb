# %% [markdown]
# <a href="https://colab.research.google.com/github/ZawYeNaung-nika/Chatbot/blob/main/California_Housing_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Data Analysis

# %%
#csv(comma sperated variable)

# %%
import pandas as pd
df = pd.read_csv('/sample.csv')

# %%
df
# Out:
#    ID       Name Classes
# 0   1     Zaw Ye      AI
# 1   2  Sint Sint  Python
# 2   3      Naung    Java

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Classes'], dtype='object')

# %%
df['Classes'].unique()
#class unique
# Out:
# array(['AI', 'Python', 'Java'], dtype=object)

# %%
df[df['Classes']=='AI']
# Out:
#    ID    Name Classes
# 0   1  Zaw Ye      AI

# %%
df[df['Name']=='Zaw Ye']
# Out:
#    ID    Name Classes
# 0   1  Zaw Ye      AI

# %%
df[df['Name']=='Sint Sint']
# Out:
#    ID       Name Classes
# 1   2  Sint Sint  Python

# %%
df.rename(columns={'Classes':'Class'}, inplace=True)

# %%
df
# Out:
#    ID       Name   Class
# 0   1     Zaw Ye      AI
# 1   2  Sint Sint  Python
# 2   3      Naung    Java

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ID, Name, Class]
# Index: []

# %%
df.isnull().any()
# Out:
# ID       False
# Name     False
# Class    False
# dtype: bool
